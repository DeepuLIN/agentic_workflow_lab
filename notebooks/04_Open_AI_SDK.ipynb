# %%
from dotenv import load_dotenv
from agents import Agent, Runner, trace

# %%
load_dotenv(override=True)
# Out:
# True

# %%
from openai import AsyncOpenAI
from agents import set_default_openai_client, set_default_openai_api

ollama_client = AsyncOpenAI(
    base_url="http://localhost:11434/v1",
    api_key="ollama"
)

set_default_openai_client(ollama_client)
set_default_openai_api("chat_completions")

# %%
agent = Agent(
    name="joketeller",
    instructions="you are tell jokes",
    model="llama3.2:latest"
)

# %%
result = await Runner.run(agent, "Tell a joke about programmers")
print(result.final_output)
# Out:
# Why do programmers prefer dark mode?
#
# Because light attracts bugs.

# %%
result.to_input_list()
# Out:
# [{'content': 'Tell a joke about programmers', 'role': 'user'},
#  {'id': '__fake_id__',
#   'content': [{'annotations': [],
#     'text': 'Why do programmers prefer dark mode?\n\nBecause light attracts bugs.',
#     'type': 'output_text'}],
#   'role': 'assistant',
#   'status': 'completed',
#   'type': 'message'}]

# %%
with trace("tell a joke about programmers"):
    result = await Runner.run(agent, "Tell a joke about programmers")
    print(result.final_output)
# Out:
# Why do programmers prefer dark mode?
#
# Because light attracts bugs.
